# %% [markdown]
# <a href="https://colab.research.google.com/github/ramzymhafeel/SE4050-Deep-Learning-Lab-01/blob/main/notebooks/SE4050_Lab01_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Markdown

display(Markdown("""
# SE4050 - Deep Learning

## Lab 01: Introduction to Python Libraries for Deep Learning

### Task 1

**Student Name:** Mohamed Ramzy
**Index Number:** IT23386822
**Module:** SE4050 - Deep Learning
**Academic Year:** 2026
"""))
# Out:
# # SE4050 - Deep Learning
#
# ## Lab 01: Introduction to Python Libraries for Deep Learning
#
# ### Task 1
#
# **Student Name:** Mohamed Ramzy
# **Index Number:** IT23386822
# **Module:** SE4050 - Deep Learning
# **Academic Year:** 2026

# %% [markdown]
# # SE4050 — Deep Learning
#
# ## Lab 01: Introduction to Python Libraries for Deep Learning
#
# ### Task 1
#
# **Student Name:** Mohamed Ramzy
# **Index Number:** IT23386822
# **Module:** SE4050 — Deep Learning
# **Academic Year:** 2026

# %% [markdown]
# ## Objective
#
# The objective of Task 1 is to apply NumPy, Matplotlib, Pandas, and Seaborn to:
#
# - Generate random numerical data
# - Visualize probability distributions
# - Create a three-dimensional mathematical surface
# - Calculate Pearson and Spearman correlations
# - Visualize correlation matrices using heatmaps

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Required libraries imported successfully.")
# Out:
# Required libraries imported successfully.

# %%
# Set a random seed so that the generated random values
# can be reproduced when the notebook is run again.

np.random.seed(42)

print("Random seed set to 42.")
# Out:
# Random seed set to 42.

# %% [markdown]
# ## Task 1.1 — Random 4×4 Array from an Exponential Distribution
#
# ### Introduction
#
# The exponential distribution is a continuous probability distribution commonly used to model the time between independent events.
#
# In this task, NumPy is used to generate a random 4×4 array from an exponential distribution.

# %% [markdown]
# ### Exponential Distribution Parameters
#
# NumPy generates exponentially distributed random values using:
#
# `np.random.exponential(scale, size)`
#
# Where:
#
# - `scale` is the inverse of the rate parameter
# - `size` defines the output dimensions
# - `size=(4, 4)` creates four rows and four columns
#
# For this task, the scale value is set to `1.0`.

# %%
import numpy as np

# Set a fixed random seed for reproducible results.
np.random.seed(42)

print("Random seed set successfully.")
# Out:
# Random seed set successfully.

# %%
# Generate a random 4×4 array from an exponential distribution.

exponential_array = np.random.exponential(
    scale=1.0,
    size=(4, 4)
)

print("Random 4×4 array from an exponential distribution:")
print(exponential_array)
# Out:
# Random 4×4 array from an exponential distribution:
# [[0.46926809 3.01012143 1.31674569 0.91294255]
#  [0.16962487 0.16959629 0.05983877 2.01123086]
#  [0.91908215 1.23125006 0.02079931 3.50355748]
#  [1.78642954 0.23868763 0.20067899 0.20261142]]

# %%
# Display values rounded to four decimal places.

print("Exponential array rounded to four decimal places:\n")
print(np.round(exponential_array, 4))
# Out:
# Exponential array rounded to four decimal places:
#
# [[0.4693 3.0101 1.3167 0.9129]
#  [0.1696 0.1696 0.0598 2.0112]
#  [0.9191 1.2313 0.0208 3.5036]
#  [1.7864 0.2387 0.2007 0.2026]]

# %%
print("Array shape:", exponential_array.shape)
print("Number of dimensions:", exponential_array.ndim)
print("Total number of elements:", exponential_array.size)
# Out:
# Array shape: (4, 4)
# Number of dimensions: 2
# Total number of elements: 16

# %%
print("Array data type:", exponential_array.dtype)
# Out:
# Array data type: float64

# %%
array_mean = np.mean(exponential_array)
array_std = np.std(exponential_array)
array_min = np.min(exponential_array)
array_max = np.max(exponential_array)

print("Basic statistics of the generated array:")
print("Mean:", round(array_mean, 4))
print("Standard deviation:", round(array_std, 4))
print("Minimum value:", round(array_min, 4))
print("Maximum value:", round(array_max, 4))
# Out:
# Basic statistics of the generated array:
# Mean: 1.0139
# Standard deviation: 1.045
# Minimum value: 0.0208
# Maximum value: 3.5036

# %%
all_non_negative = np.all(exponential_array >= 0)

print("Are all values non-negative?", all_non_negative)
# Out:
# Are all values non-negative? True

# %%
import pandas as pd

array_df = pd.DataFrame(
    exponential_array,
    columns=["Column 1", "Column 2", "Column 3", "Column 4"],
    index=["Row 1", "Row 2", "Row 3", "Row 4"]
)

array_df.round(4)
# Out:
#        Column 1  Column 2  Column 3  Column 4
# Row 1    0.4693    3.0101    1.3167    0.9129
# Row 2    0.1696    0.1696    0.0598    2.0112
# Row 3    0.9191    1.2313    0.0208    3.5036
# Row 4    1.7864    0.2387    0.2007    0.2026

# %% [markdown]
# ### Interpretation
#
# A 4×4 NumPy array containing 16 random values was generated successfully from an exponential distribution.
#
# The array contains only non-negative floating-point values, which is consistent with the properties of an exponential distribution.
#
# The shape `(4, 4)` confirms that the generated array contains four rows and four columns.

# %%
# Task 1.1: Generate a random 4×4 array
# from an exponential distribution.

import numpy as np

np.random.seed(42)

exponential_array = np.random.exponential(
    scale=1.0,
    size=(4, 4)
)

print("Random 4×4 exponential-distribution array:\n")
print(np.round(exponential_array, 4))

print("\nArray shape:", exponential_array.shape)
print("Number of elements:", exponential_array.size)
print("All values are non-negative:",
      np.all(exponential_array >= 0))
# Out:
# Random 4×4 exponential-distribution array:
#
# [[0.4693 3.0101 1.3167 0.9129]
#  [0.1696 0.1696 0.0598 2.0112]
#  [0.9191 1.2313 0.0208 3.5036]
#  [1.7864 0.2387 0.2007 0.2026]]
#
# Array shape: (4, 4)
# Number of elements: 16
# All values are non-negative: True

# %% [markdown]
# ## Task 1.2 — Visualization of Exponential, Uniform, and Normal Distributions
#
# ### Introduction
#
# In this task, three probability distributions are generated and compared:
#
# - Exponential distribution
# - Uniform distribution
# - Normal distribution
#
# Each distribution contains 100,000 random values. Their probability density shapes are visualized using histograms.

# %% [markdown]
# ### Distribution Characteristics
#
# **Exponential distribution:**
# Produces non-negative values and is usually right-skewed.
#
# **Uniform distribution:**
# Produces values with approximately equal probability across a specified range.
#
# **Normal distribution:**
# Produces a symmetric bell-shaped distribution centered around the mean.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the random seed for reproducible results.
np.random.seed(42)

print("Random seed set successfully.")
# Out:
# Random seed set successfully.

# %%
# Generate 100,000 values from an exponential distribution.
# The reshape operation creates a 100000 × 1 array.

exponential_data = np.random.exponential(
    scale=1.0,
    size=100000
).reshape(100000, 1)

print("Exponential data shape:", exponential_data.shape)
print("First five values:\n", exponential_data[:5])
# Out:
# Exponential data shape: (100000, 1)
# First five values:
#  [[0.46926809]
#  [3.01012143]
#  [1.31674569]
#  [0.91294255]
#  [0.16962487]]

# %%
# Generate 100,000 values from a uniform distribution
# between 0 and 1.

uniform_data = np.random.uniform(
    low=0.0,
    high=1.0,
    size=100000
)

print("Uniform data shape:", uniform_data.shape)
print("First five values:", uniform_data[:5])
# Out:
# Uniform data shape: (100000,)
# First five values: [0.58077904 0.52697165 0.35103695 0.49321266 0.36509664]

# %%
# Generate 100,000 values from a standard normal distribution.
# Mean = 0 and standard deviation = 1.

normal_data = np.random.normal(
    loc=0.0,
    scale=1.0,
    size=100000
)

print("Normal data shape:", normal_data.shape)
print("First five values:", normal_data[:5])
# Out:
# Normal data shape: (100000,)
# First five values: [-0.33715797 -1.77386619 -0.1212223  -0.91386948 -0.65504833]

# %%
exponential_plot_data = exponential_data.flatten()

print("Original shape:", exponential_data.shape)
print("Plotting shape:", exponential_plot_data.shape)
# Out:
# Original shape: (100000, 1)
# Plotting shape: (100000,)

# %%
plt.figure(figsize=(12, 7))

plt.hist(
    exponential_plot_data,
    density=True,
    bins=150,
    histtype="step",
    linewidth=2,
    label="Exponential Distribution"
)

plt.hist(
    uniform_data,
    density=True,
    bins=150,
    histtype="step",
    linewidth=2,
    label="Uniform Distribution"
)

plt.hist(
    normal_data,
    density=True,
    bins=150,
    histtype="step",
    linewidth=2,
    label="Normal Distribution"
)

plt.axis([-3, 6, 0, 1.2])

plt.title(
    "Comparison of Exponential, Uniform, and Normal Distributions",
    fontsize=14
)

plt.xlabel("Value", fontsize=12)
plt.ylabel("Probability Density", fontsize=12)

plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Selection of Histogram Bins
#
# The original example uses 100 bins. In this implementation, the number of bins was increased to 150.
#
# Using 150 bins provides a more detailed view because the dataset contains 100,000 observations. It improves the visibility of each distribution while keeping the graph readable.

# %% [markdown]
# ### Plot View
#
# The x-axis is limited to the range `[-3, 6]` so that the important regions of all three distributions can be compared clearly.
#
# The y-axis is limited to `[0, 1.2]` to keep the highest-density regions visible without creating excessive empty space.

# %%
print("Exponential distribution:")
print("Mean:", round(np.mean(exponential_plot_data), 4))
print("Standard deviation:",
      round(np.std(exponential_plot_data), 4))
print("Minimum:", round(np.min(exponential_plot_data), 4))
print("Maximum:", round(np.max(exponential_plot_data), 4))

print("\nUniform distribution:")
print("Mean:", round(np.mean(uniform_data), 4))
print("Standard deviation:",
      round(np.std(uniform_data), 4))
print("Minimum:", round(np.min(uniform_data), 4))
print("Maximum:", round(np.max(uniform_data), 4))

print("\nNormal distribution:")
print("Mean:", round(np.mean(normal_data), 4))
print("Standard deviation:",
      round(np.std(normal_data), 4))
print("Minimum:", round(np.min(normal_data), 4))
print("Maximum:", round(np.max(normal_data), 4))
# Out:
# Exponential distribution:
# Mean: 0.996
# Standard deviation: 0.993
# Minimum: 0.0
# Maximum: 11.7414
#
# Uniform distribution:
# Mean: 0.5013
# Standard deviation: 0.2887
# Minimum: 0.0
# Maximum: 1.0
#
# Normal distribution:
# Mean: -0.0026
# Standard deviation: 1.0007
# Minimum: -4.4139
# Maximum: 4.2194

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].hist(
    exponential_plot_data,
    bins=100,
    density=True,
    edgecolor="black"
)
axes[0].set_title("Exponential Distribution")
axes[0].set_xlabel("Value")
axes[0].set_ylabel("Density")
axes[0].set_xlim(0, 6)
axes[0].grid(alpha=0.3)

axes[1].hist(
    uniform_data,
    bins=100,
    density=True,
    edgecolor="black"
)
axes[1].set_title("Uniform Distribution")
axes[1].set_xlabel("Value")
axes[1].set_ylabel("Density")
axes[1].set_xlim(0, 1)
axes[1].grid(alpha=0.3)

axes[2].hist(
    normal_data,
    bins=100,
    density=True,
    edgecolor="black"
)
axes[2].set_title("Normal Distribution")
axes[2].set_xlabel("Value")
axes[2].set_ylabel("Density")
axes[2].set_xlim(-4, 4)
axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The three histograms demonstrate clearly different probability-distribution shapes.
#
# - The exponential distribution is positively skewed. Most values occur near zero, while fewer large values appear toward the right.
# - The uniform distribution is approximately flat between zero and one, showing that values in this interval have similar probabilities.
# - The normal distribution is approximately symmetric and bell-shaped around zero.
#
# The visualization confirms that probability distributions can have different ranges, levels of symmetry, and density patterns.

# %%
# Task 1.2: Compare exponential, uniform,
# and normal distributions.

import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

exponential_data = np.random.exponential(
    scale=1.0,
    size=100000
).reshape(100000, 1)

uniform_data = np.random.uniform(
    low=0.0,
    high=1.0,
    size=100000
)

normal_data = np.random.normal(
    loc=0.0,
    scale=1.0,
    size=100000
)

plt.figure(figsize=(12, 7))

plt.hist(
    exponential_data.flatten(),
    density=True,
    bins=150,
    histtype="step",
    linewidth=2,
    label="Exponential"
)

plt.hist(
    uniform_data,
    density=True,
    bins=150,
    histtype="step",
    linewidth=2,
    label="Uniform"
)

plt.hist(
    normal_data,
    density=True,
    bins=150,
    histtype="step",
    linewidth=2,
    label="Normal"
)

plt.axis([-3, 6, 0, 1.2])
plt.title("Random Distribution Comparison")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print("Exponential array shape:", exponential_data.shape)
# Out:
# Exponential array shape: (100000, 1)

# %% [markdown]
# ## Task 1.3 — Three-Dimensional Plot of Z = X² + Y²
#
# ### Introduction
#
# In this task, the mathematical function
#
# `Z = X² + Y²`
#
# is visualized as a three-dimensional surface.
#
# The values of both `X` and `Y` are limited to the interval `[-5, 5]`. Since both variables are squared, the resulting surface forms an upward-opening paraboloid.

# %%
import numpy as np
import matplotlib.pyplot as plt

print("Required libraries imported successfully.")
# Out:
# Required libraries imported successfully.

# %%
# Generate 100 evenly spaced values from -5 to 5.

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

print("Number of X values:", len(x))
print("Number of Y values:", len(y))

print("X range:", x.min(), "to", x.max())
print("Y range:", y.min(), "to", y.max())
# Out:
# Number of X values: 100
# Number of Y values: 100
# X range: -5.0 to 5.0
# Y range: -5.0 to 5.0

# %%
# Convert the one-dimensional X and Y arrays
# into two-dimensional coordinate matrices.

X, Y = np.meshgrid(x, y)

print("X grid shape:", X.shape)
print("Y grid shape:", Y.shape)
# Out:
# X grid shape: (100, 100)
# Y grid shape: (100, 100)

# %%
# Calculate Z for every X and Y coordinate.

Z = X**2 + Y**2

print("Z grid shape:", Z.shape)
print("Minimum Z value:", Z.min())
print("Maximum Z value:", Z.max())
# Out:
# Z grid shape: (100, 100)
# Minimum Z value: 0.005101520253035336
# Maximum Z value: 50.0

# %%
fig = plt.figure(figsize=(10, 8))

ax = fig.add_subplot(
    111,
    projection="3d"
)

ax.plot_surface(X, Y, Z)

ax.set_title("3D Plot of Z = X² + Y²")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

plt.show()

# %%
fig = plt.figure(figsize=(12, 9))

ax = fig.add_subplot(
    111,
    projection="3d"
)

surface = ax.plot_surface(
    X,
    Y,
    Z,
    cmap="viridis",
    edgecolor="none"
)

ax.set_title(
    "Three-Dimensional Surface of Z = X² + Y²",
    fontsize=15,
    pad=20
)

ax.set_xlabel("X Values", fontsize=11, labelpad=10)
ax.set_ylabel("Y Values", fontsize=11, labelpad=10)
ax.set_zlabel("Z Values", fontsize=11, labelpad=10)

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)

fig.colorbar(
    surface,
    ax=ax,
    shrink=0.65,
    aspect=12,
    label="Z Value"
)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(12, 9))

ax = fig.add_subplot(
    111,
    projection="3d"
)

surface = ax.plot_surface(
    X,
    Y,
    Z,
    cmap="viridis",
    edgecolor="none",
    alpha=0.9
)

ax.view_init(
    elev=30,
    azim=45
)

ax.set_title(
    "3D Paraboloid: Z = X² + Y²",
    fontsize=15,
    pad=20
)

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)

fig.colorbar(
    surface,
    ax=ax,
    shrink=0.65,
    label="Z Value"
)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))

ax = fig.add_subplot(
    111,
    projection="3d"
)

ax.plot_wireframe(
    X,
    Y,
    Z,
    rstride=5,
    cstride=5
)

ax.set_title("Wireframe Plot of Z = X² + Y²")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)

plt.tight_layout()
plt.show()

# %%
# Verify selected coordinate calculations.

test_coordinates = [
    (0, 0),
    (1, 2),
    (-3, 4),
    (5, 5)
]

for x_value, y_value in test_coordinates:
    z_value = x_value**2 + y_value**2

    print(
        f"When X = {x_value} and Y = {y_value}, "
        f"Z = {z_value}"
    )
# Out:
# When X = 0 and Y = 0, Z = 0
# When X = 1 and Y = 2, Z = 5
# When X = -3 and Y = 4, Z = 25
# When X = 5 and Y = 5, Z = 50

# %% [markdown]
# ### Interpretation
#
# The graph forms an upward-opening paraboloid.
#
# The smallest value of `Z` occurs near the center, where both `X` and `Y` are close to zero. As the absolute values of `X` and `Y` increase, the value of `Z` also increases.
#
# Because `X` and `Y` are squared, positive and negative input values produce the same contribution to `Z`. Therefore, the surface is symmetric around both the X-axis and the Y-axis.

# %%
# Task 1.3: Plot Z = X² + Y² as a 3D surface.

import numpy as np
import matplotlib.pyplot as plt

# Create X and Y values within the required range.
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

# Create a two-dimensional coordinate grid.
X, Y = np.meshgrid(x, y)

# Calculate Z.
Z = X**2 + Y**2

# Create the three-dimensional plot.
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111, projection="3d")

surface = ax.plot_surface(
    X,
    Y,
    Z,
    cmap="viridis",
    edgecolor="none"
)

ax.set_title("3D Surface Plot of Z = X² + Y²")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.view_init(elev=30, azim=45)

fig.colorbar(
    surface,
    ax=ax,
    shrink=0.65,
    label="Z Value"
)

plt.tight_layout()
plt.show()

print("X range:", X.min(), "to", X.max())
print("Y range:", Y.min(), "to", Y.max())
print("Z range:", round(Z.min(), 4), "to", Z.max())
# Out:
# X range: -5.0 to 5.0
# Y range: -5.0 to 5.0
# Z range: 0.0051 to 50.0

# %% [markdown]
# ## Task 1.4 — Pearson and Spearman Correlation Analysis
